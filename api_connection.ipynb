# %%
import requests

url = "https://xeno-canto.org/api/3/recordings"

params = {
    "query": 'cnt:"Colombia"', 
    "key" : "1cb9951b67dbd5be783fae428acf24ac773356fc"
}

headers = {
    "Authorization": "1cb9951b67dbd5be783fae428acf24ac773356fc",
    "Content-Type": "application/json",
}

response = requests.get(url, params=params, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 200
# {
#     "numRecordings": "37242",
#     "numSpecies": "1621",
#     "page": 1,
#     "numPages": 373,
#     "recordings": [
#         {
#             "id": "568023",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/568023",
#             "file": "https://xeno-canto.org/568023/download",
#             "file-name": "XC568023-Rufous-capped Warbler, call, Mana Dulce, 200531-011.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/568023/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/568023/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/568023/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/568023/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:48",
#             "time": "16:00",
#             "date": "2020-05-31",
#             "uploaded": "2020-06-13",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "562169",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/562169",
#             "file": "https://xeno-canto.org/562169/download",
#             "file-name": "XC562169-Rufous-capped Warbler, call, Mana Dulce, 200524-002.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562169/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562169/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562169/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562169/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:13",
#             "time": "17:00",
#             "date": "2020-05-24",
#             "uploaded": "2020-05-26",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "562165",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "call",
#             "sex": "",
#             "stage": "juvenile",
#             "method": "field recording",
#             "url": "//xeno-canto.org/562165",
#             "file": "https://xeno-canto.org/562165/download",
#             "file-name": "XC562165-Rufous-capped Warbler, juv. Mana Dulce, 200524-014.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562165/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562165/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562165/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/562165/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:26",
#             "time": "17:00",
#             "date": "2020-05-24",
#             "uploaded": "2020-05-26",
#             "also": [],
#             "rmk": "juvenile being fed by adult",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "560765",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/560765",
#             "file": "https://xeno-canto.org/560765/download",
#             "file-name": "XC560765-Rufous-capped Warbler, 16.4.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/560765/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/560765/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/560765/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/560765/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:20",
#             "time": "17:00",
#             "date": "2020-04-16",
#             "uploaded": "2020-05-22",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "552747",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/552747",
#             "file": "https://xeno-canto.org/552747/download",
#             "file-name": "XC552747-Rufous-capped Warbler, 13.4..mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/552747/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/552747/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/552747/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/552747/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:33",
#             "time": "08:00",
#             "date": "2020-04-13",
#             "uploaded": "2020-05-01",
#             "also": [],
#             "rmk": "adult bird feeding juvenile",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "542031",
#             "gen": "Saltator",
#             "sp": "olivascens",
#             "ssp": "plumbeus",
#             "grp": "birds",
#             "en": "Olivaceous Saltator",
#             "rec": "Cristhian David Gaitán García",
#             "cnt": "Colombia",
#             "loc": "Ibagué, Tolima",
#             "lat": "4.447",
#             "lon": "-75.1535",
#             "alt": "1000",
#             "type": "song",
#             "sex": "uncertain",
#             "stage": "uncertain",
#             "method": "field recording",
#             "url": "//xeno-canto.org/542031",
#             "file": "https://xeno-canto.org/542031/download",
#             "file-name": "XC542031-Saltator coerulescens.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/UWUNFMJPTF/542031/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/UWUNFMJPTF/542031/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/UWUNFMJPTF/542031/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/UWUNFMJPTF/542031/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:05",
#             "time": "07:30",
#             "date": "2020-04-05",
#             "uploaded": "2020-04-05",
#             "also": [],
#             "rmk": "Archivo filtrado y acortado entre intervalos.\r\n\r\nIndividuo es escuchado en una zona arbolada en una unidad residencial",
#             "animal-seen": "unknown",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "24000",
#             "annotation-set": []
#         },
#         {
#             "id": "540091",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/540091",
#             "file": "https://xeno-canto.org/540091/download",
#             "file-name": "XC540091-Rufous-capped Warbler.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/540091/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/540091/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/540091/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/540091/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:37",
#             "time": "10:30",
#             "date": "2020-03-26",
#             "uploaded": "2020-03-31",
#             "also": [
#                 "Sporophila nigricollis",
#                 "Saltator striatipectus",
#                 "Nystalus radiatus",
#                 "Phaeomyias murina"
#             ],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "525017",
#             "gen": "Saltator",
#             "sp": "olivascens",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Olivaceous Saltator",
#             "rec": "Mauricio Álvarez-Rebolledo",
#             "cnt": "Colombia",
#             "loc": "Isla de Tierra Bomba",
#             "lat": "10.36",
#             "lon": "-75.5697222",
#             "alt": "100",
#             "type": "",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/525017",
#             "file": "https://xeno-canto.org/525017/download",
#             "file-name": "XC525017-x_IAvH-CSA-5064.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525017/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525017/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525017/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525017/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:29",
#             "time": "?",
#             "date": "1996-01-08",
#             "uploaded": "2020-02-07",
#             "also": [],
#             "rmk": "Grabado por Mauricio Alvarez Rebolledo el 8/1/1996 en Isla de Tierra Bomba en Bolívar a los 100 msnm",
#             "animal-seen": "no",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "525016",
#             "gen": "Saltator",
#             "sp": "olivascens",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Olivaceous Saltator",
#             "rec": "Mauricio Álvarez-Rebolledo",
#             "cnt": "Colombia",
#             "loc": "Isla de Tierra Bomba",
#             "lat": "10.36",
#             "lon": "-75.5697222",
#             "alt": "100",
#             "type": "",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/525016",
#             "file": "https://xeno-canto.org/525016/download",
#             "file-name": "XC525016-x_IAvH-CSA-5029.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525016/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525016/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525016/colour.png",
#                 "full": ""
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "2:28",
#             "time": "?",
#             "date": "1996-01-08",
#             "uploaded": "2020-02-07",
#             "also": [],
#             "rmk": "Grabado por Mauricio Alvarez Rebolledo el 8/1/1996 en Isla de Tierra Bomba en Bolívar a los 100 msnm",
#             "animal-seen": "no",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "525015",
#             "gen": "Saltator",
#             "sp": "olivascens",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Olivaceous Saltator",
#             "rec": "Mauricio Álvarez-Rebolledo",
#             "cnt": "Colombia",
#             "loc": "Isla de Tierra Bomba",
#             "lat": "10.36",
#             "lon": "-75.5697222",
#             "alt": "100",
#             "type": "",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/525015",
#             "file": "https://xeno-canto.org/525015/download",
#             "file-name": "XC525015-x_IAvH-CSA-5011.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525015/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525015/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525015/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525015/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:42",
#             "time": "?",
#             "date": "1996-01-08",
#             "uploaded": "2020-02-07",
#             "also": [],
#             "rmk": "Grabado por Mauricio Alvarez Rebolledo el 8/1/1996 en Isla de Tierra Bomba en Bolívar a los 100 msnm",
#             "animal-seen": "no",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "525014",
#             "gen": "Saltator",
#             "sp": "olivascens",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Olivaceous Saltator",
#             "rec": "Mauricio Álvarez-Rebolledo",
#             "cnt": "Colombia",
#             "loc": "Isla de Tierra Bomba",
#             "lat": "10.36",
#             "lon": "-75.5697222",
#             "alt": "100",
#             "type": "",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/525014",
#             "file": "https://xeno-canto.org/525014/download",
#             "file-name": "XC525014-x_IAvH-CSA-5010.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525014/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525014/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525014/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/XMFDPACYJN/525014/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "1:14",
#             "time": "?",
#             "date": "1996-01-08",
#             "uploaded": "2020-02-07",
#             "also": [],
#             "rmk": "Grabado por Mauricio Alvarez Rebolledo el 8/1/1996 en Isla de Tierra Bomba en Bolívar a los 100 msnm",
#             "animal-seen": "no",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "502836",
#             "gen": "Saltator",
#             "sp": "olivascens",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Olivaceous Saltator",
#             "rec": "Arcadio Marin ",
#             "cnt": "Colombia",
#             "loc": "Talauta, El Peñón, Cundinamarca",
#             "lat": "5.2437",
#             "lon": "-74.3056",
#             "alt": "1000",
#             "type": "song",
#             "sex": "male",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/502836",
#             "file": "https://xeno-canto.org/502836/download",
#             "file-name": "XC502836-Saltator coerulescens.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/TNYAZUJQBM/502836/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/TNYAZUJQBM/502836/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/TNYAZUJQBM/502836/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/TNYAZUJQBM/502836/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:04",
#             "time": "09:30",
#             "date": "2018-09-17",
#             "uploaded": "2019-10-17",
#             "also": [],
#             "rmk": "vocalizacion ligeramente editada en (Adobe Audition) para reducion de ruido y aumentar un poco el volumen, no se hicieron recortes",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "492567",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "David Ricardo Rodríguez-Villamil",
#             "cnt": "Colombia",
#             "loc": "Paquiló, Beltrán, Cundinamarca",
#             "lat": "4.6709",
#             "lon": "-74.7781",
#             "alt": "280",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/492567",
#             "file": "https://xeno-canto.org/492567/download",
#             "file-name": "XC492567-a362. Basileuterus rufifrons. Paquiló. Cundinamarca. DRRV.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/GSINAVRFEN/492567/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/GSINAVRFEN/492567/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/GSINAVRFEN/492567/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/GSINAVRFEN/492567/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:18",
#             "time": "02:02",
#             "date": "2017-12-06",
#             "uploaded": "2019-08-14",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "unknown",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "428318",
#             "gen": "Basileuterus",
#             "sp": "delattrii",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Chestnut-capped Warbler",
#             "rec": "Jerome Fischer",
#             "cnt": "Colombia",
#             "loc": "Mana Dulce, Cundinamarca",
#             "lat": "4.351",
#             "lon": "-74.652",
#             "alt": "380",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/428318",
#             "file": "https://xeno-canto.org/428318/download",
#             "file-name": "XC428318-Rufous-capped Warbler, 180722-000.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/428318/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/428318/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/428318/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/JPBSNBUUEF/428318/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "no score",
#             "length": "0:22",
#             "time": "06:00",
#             "date": "2018-07-21",
#             "uploaded": "2018-07-25",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "1090676",
#             "gen": "Dendropsophus",
#             "sp": "norandinus",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Andres Montoya-Lopez",
#             "cnt": "Colombia",
#             "loc": "Carmen de Viboral, Antioquia",
#             "lat": "5.9188",
#             "lon": "-75.2738",
#             "alt": "2100",
#             "type": "advertisement call",
#             "sex": "male",
#             "stage": "",
#             "method": "in the hand",
#             "url": "//xeno-canto.org/1090676",
#             "file": "https://xeno-canto.org/1090676/download",
#             "file-name": "XC1090676-norandinus_La_Honda2.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/CHSWIKRAKN/1090676/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/CHSWIKRAKN/1090676/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/CHSWIKRAKN/1090676/colour.png",
#                 "full": ""
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "2:02",
#             "time": "20:00",
#             "date": "2026-03-17",
#             "uploaded": "2026-03-23",
#             "also": [],
#             "rmk": "Pond with abundant Cyperaceae along the margins. Dendropsophus norandinus calling from within the vegetation or at the water surface",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "16000",
#             "annotation-set": []
#         },
#         {
#             "id": "1084659",
#             "gen": "Boana",
#             "sp": "rufitela",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Valentina Ojeda ",
#             "cnt": "Colombia",
#             "loc": "Unión Panamericana, Choco",
#             "lat": "5.3495",
#             "lon": "-76.624",
#             "alt": "110",
#             "type": "uncertain",
#             "sex": "uncertain",
#             "stage": "adult",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1084659",
#             "file": "https://xeno-canto.org/1084659/download",
#             "file-name": "XC1084659-AJC7953-Boana-rufitela-2023-10-17.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084659/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084659/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084659/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084659/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:33",
#             "time": "18:30",
#             "date": "2023-10-17",
#             "uploaded": "2026-03-04",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "23",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "Marantz PMD 661",
#             "mic": "Unidirectional",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1084658",
#             "gen": "Dendropsophus",
#             "sp": "phlebodes",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "San Carlos Dwarf Treefrog",
#             "rec": "Valentina Ojeda ",
#             "cnt": "Colombia",
#             "loc": "Unión Panamericana, Choco",
#             "lat": "5.3495",
#             "lon": "-76.624",
#             "alt": "110",
#             "type": "uncertain",
#             "sex": "uncertain",
#             "stage": "adult",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1084658",
#             "file": "https://xeno-canto.org/1084658/download",
#             "file-name": "XC1084658-AJC7952-Dendropsophus-phlebodes-2023-10-17.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084658/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084658/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084658/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084658/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:37",
#             "time": "18:30",
#             "date": "2023-10-17",
#             "uploaded": "2026-03-04",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "23",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "Marantz PMD 661",
#             "mic": "Unidirectional",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1084654",
#             "gen": "Boana",
#             "sp": "boans",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "Giant Gladiator Treefrog",
#             "rec": "Valentina Ojeda ",
#             "cnt": "Colombia",
#             "loc": "Unión Panamericana, Choco",
#             "lat": "5.3495",
#             "lon": "-76.624",
#             "alt": "110",
#             "type": "uncertain",
#             "sex": "uncertain",
#             "stage": "adult",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1084654",
#             "file": "https://xeno-canto.org/1084654/download",
#             "file-name": "XC1084654-2023-10-17-Boana-boans.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084654/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084654/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084654/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084654/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:37",
#             "time": "20:30",
#             "date": "2023-10-17",
#             "uploaded": "2026-03-04",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "23",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "Marantz PMD 661",
#             "mic": "Unidirectional",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1084652",
#             "gen": "Diasporus",
#             "sp": "tinker",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Valentina Ojeda ",
#             "cnt": "Colombia",
#             "loc": "Unión Panamericana, Choco",
#             "lat": "5.3495",
#             "lon": "-76.624",
#             "alt": "110",
#             "type": "uncertain",
#             "sex": "uncertain",
#             "stage": "adult",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1084652",
#             "file": "https://xeno-canto.org/1084652/download",
#             "file-name": "XC1084652-2023-10-16-Diasporus-tinker.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084652/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084652/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084652/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/EYAPATRSZW/1084652/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:28",
#             "time": "20:00",
#             "date": "2023-10-16",
#             "uploaded": "2026-03-04",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "22",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "Marantz PMD 661",
#             "mic": "Unidirectional",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1083971",
#             "gen": "Aquarana",
#             "sp": "catesbeiana",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "American Bullfrog",
#             "rec": "Carlos Delgado JUMABITA",
#             "cnt": "Colombia",
#             "loc": "Laguna de Sonso, Valle del Cauca",
#             "lat": "3.862",
#             "lon": "-76.3492",
#             "alt": "950",
#             "type": "",
#             "sex": "uncertain",
#             "stage": "uncertain",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1083971",
#             "file": "https://xeno-canto.org/1083971/download",
#             "file-name": "XC1083971-RANA-TORO-AMERICAN-BULLFROG-260221_001.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/QNQOLYYZEB/1083971/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/QNQOLYYZEB/1083971/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/QNQOLYYZEB/1083971/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/QNQOLYYZEB/1083971/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:35",
#             "time": "08:30",
#             "date": "2026-02-21",
#             "uploaded": "2026-03-01",
#             "also": [
#                 "Forpus conspicillatus"
#             ],
#             "rmk": "",
#             "animal-seen": "no",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "SONY PCM D100",
#             "mic": "XY",
#             "smp": "192000",
#             "annotation-set": []
#         },
#         {
#             "id": "1083545",
#             "gen": "Dendropsophus",
#             "sp": "molitor",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "Green Dotted Treefrog",
#             "rec": "Paul Stewart - En8patas",
#             "cnt": "Colombia",
#             "loc": "Humedal Santa María del Lago",
#             "lat": "4.695",
#             "lon": "-74.0942",
#             "alt": "2500",
#             "type": "Grupal",
#             "sex": "uncertain",
#             "stage": "uncertain",
#             "method": "unknown",
#             "url": "//xeno-canto.org/1083545",
#             "file": "https://xeno-canto.org/1083545/download",
#             "file-name": "XC1083545-Canto-grupal-rana-sabanera.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083545/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083545/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083545/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083545/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:16",
#             "time": "19:30",
#             "date": "2025-10-06",
#             "uploaded": "2026-02-27",
#             "also": [
#                 "Dendropsophus molitor"
#             ],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "13",
#             "regnr": "",
#             "auto": "yes",
#             "dvc": "",
#             "mic": "Celular",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "1083544",
#             "gen": "Dendropsophus",
#             "sp": "molitor",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "Green Dotted Treefrog",
#             "rec": "Paul Stewart - En8patas",
#             "cnt": "Colombia",
#             "loc": "Humedal Capellanía, Bogotá",
#             "lat": "4.675",
#             "lon": "-74.1308",
#             "alt": "2500",
#             "type": "uncertain, call",
#             "sex": "uncertain",
#             "stage": "uncertain",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1083544",
#             "file": "https://xeno-canto.org/1083544/download",
#             "file-name": "XC1083544-Rana-sabanera.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083544/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083544/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083544/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/GNFKJLXNDU/1083544/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:16",
#             "time": "12:30",
#             "date": "2026-01-30",
#             "uploaded": "2026-02-27",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "20",
#             "regnr": "",
#             "auto": "yes",
#             "dvc": "",
#             "mic": "Celular",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "1069627",
#             "gen": "Pristimantis",
#             "sp": "labiosus",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Fabrice Schmitt",
#             "cnt": "Colombia",
#             "loc": "Reserva Natural río Ñambí, Vereda el Barro, Altaquer, Barbacoas, Nariño.",
#             "lat": "1.3001",
#             "lon": "-78.0834",
#             "alt": "1420",
#             "type": "territorial call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1069627",
#             "file": "https://xeno-canto.org/1069627/download",
#             "file-name": "XC1069627-Pristimantis-labiosus_25fev2025_RioNambi_Co_FSchmitt-(4).wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069627/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069627/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069627/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069627/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:06",
#             "time": "21:30",
#             "date": "2025-02-25",
#             "uploaded": "2025-12-31",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "no",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "MixPre 3",
#             "mic": "Sennheiser M66+K6",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1069626",
#             "gen": "Pristimantis",
#             "sp": "labiosus",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Fabrice Schmitt",
#             "cnt": "Colombia",
#             "loc": "Reserva Natural río Ñambí, Vereda el Barro, Altaquer, Barbacoas, Nariño.",
#             "lat": "1.3001",
#             "lon": "-78.0834",
#             "alt": "1420",
#             "type": "territorial call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1069626",
#             "file": "https://xeno-canto.org/1069626/download",
#             "file-name": "XC1069626-Pristimantis-labiosus_25fev2025_RioNambi_Co_FSchmitt-(3).wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069626/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069626/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069626/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069626/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:05",
#             "time": "21:30",
#             "date": "2025-02-25",
#             "uploaded": "2025-12-31",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "no",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "MixPre 3",
#             "mic": "Sennheiser M66+K6",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1069625",
#             "gen": "Pristimantis",
#             "sp": "labiosus",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Fabrice Schmitt",
#             "cnt": "Colombia",
#             "loc": "Reserva Natural río Ñambí, Vereda el Barro, Altaquer, Barbacoas, Nariño.",
#             "lat": "1.3001",
#             "lon": "-78.0834",
#             "alt": "1420",
#             "type": "territorial call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1069625",
#             "file": "https://xeno-canto.org/1069625/download",
#             "file-name": "XC1069625-Pristimantis-labiosus_25fev2025_RioNambi_Co_FSchmitt-(2).wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069625/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069625/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069625/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069625/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:04",
#             "time": "21:30",
#             "date": "2025-02-25",
#             "uploaded": "2025-12-31",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "no",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "MixPre 3",
#             "mic": "Sennheiser M66+K6",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1069624",
#             "gen": "Pristimantis",
#             "sp": "achatinus",
#             "ssp": "",
#             "grp": "frogs",
#             "en": "",
#             "rec": "Fabrice Schmitt",
#             "cnt": "Colombia",
#             "loc": "Reserva Natural río Ñambí, Vereda el Barro, Altaquer, Barbacoas, Nariño.",
#             "lat": "1.3001",
#             "lon": "-78.0834",
#             "alt": "1420",
#             "type": "uncertain",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/1069624",
#             "file": "https://xeno-canto.org/1069624/download",
#             "file-name": "XC1069624-Pristimantis-achatinus_25fev2025_RioNambi_Co_FSchmitt.wav",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069624/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069624/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069624/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/1069624/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:53",
#             "time": "20:30",
#             "date": "2025-02-25",
#             "uploaded": "2025-12-31",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "MixPre 3",
#             "mic": "Sennheiser M66+K6",
#             "smp": "48000",
#             "annotation-set": []
#         },
#         {
#             "id": "1069623",
#             "gen": "Microsciurus",
#             "sp": "mimulus",
#             "ssp": "",
# ...
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "235763",
#             "gen": "Grallaria",
#             "sp": "spatiator",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Sierra Nevada Antpitta",
#             "rec": "Niels Krabbe",
#             "cnt": "Colombia",
#             "loc": "Magdalena: San Lorenzo ridge, Sierra Nevada de Santa Marta",
#             "lat": "11.1009",
#             "lon": "-74.072",
#             "alt": "2580",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/235763",
#             "file": "https://xeno-canto.org/235763/download",
#             "file-name": "XC235763-Grallaria_rufula_2007_02_04_B_449.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235763/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235763/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235763/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235763/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:12",
#             "time": "07:00",
#             "date": "2007-02-04",
#             "uploaded": "2015-04-15",
#             "also": [],
#             "rmk": "Humid forest. Krabbe (2008) cut 4. Tape reference: B 449.",
#             "animal-seen": "no",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "235762",
#             "gen": "Grallaria",
#             "sp": "spatiator",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Sierra Nevada Antpitta",
#             "rec": "Niels Krabbe",
#             "cnt": "Colombia",
#             "loc": "Magdalena: San Lorenzo ridge, Sierra Nevada de Santa Marta",
#             "lat": "11.1009",
#             "lon": "-74.072",
#             "alt": "2580",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/235762",
#             "file": "https://xeno-canto.org/235762/download",
#             "file-name": "XC235762-Grallaria_rufula_2007_02_04_B_197.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235762/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235762/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235762/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235762/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:10",
#             "time": "06:05",
#             "date": "2007-02-04",
#             "uploaded": "2015-04-15",
#             "also": [],
#             "rmk": "Humid forest. Krabbe (2008) cut 3. Tape reference: B 197.",
#             "animal-seen": "no",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "235761",
#             "gen": "Grallaria",
#             "sp": "spatiator",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Sierra Nevada Antpitta",
#             "rec": "Niels Krabbe",
#             "cnt": "Colombia",
#             "loc": "Magdalena: San Lorenzo ridge, Sierra Nevada de Santa Marta",
#             "lat": "11.1009",
#             "lon": "-74.072",
#             "alt": "2550",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/235761",
#             "file": "https://xeno-canto.org/235761/download",
#             "file-name": "XC235761-Grallaria_rufula_2007_02_03_A_168-177.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235761/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235761/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235761/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/XTVEPHMPPJ/235761/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:52",
#             "time": "07:30",
#             "date": "2007-02-03",
#             "uploaded": "2015-04-15",
#             "also": [],
#             "rmk": "Bamboo thicket in humid forest. Krabbe (2008) cut 2. Tape reference: A 168-177.",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "234289",
#             "gen": "Grallaria",
#             "sp": "saltuensis",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Perija Antpitta",
#             "rec": "Andres M. Cuervo",
#             "cnt": "Colombia",
#             "loc": "Cesar, Manaure, Serranía del Perijá, arriba de El Cinco",
#             "lat": "10.3643",
#             "lon": "-72.9458",
#             "alt": "2525",
#             "type": "call, short song?",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/234289",
#             "file": "https://xeno-canto.org/234289/download",
#             "file-name": "XC234289-saltuensis_137_AMC896.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234289/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234289/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234289/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234289/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "1:19",
#             "time": "07:51",
#             "date": "2008-07-13",
#             "uploaded": "2015-04-05",
#             "also": [
#                 "Zimmerius improbus",
#                 "Catharus fuscater",
#                 "Diglossa albilatera",
#                 "Zonotrichia capensis"
#             ],
#             "rmk": "Perija 137 - same male as in [XC234286](http://www.xeno-canto.org/234286) but this one after brief playback. Collected (ICN 36771). Check out this paper by López-O. et al. 2014 in Ornitología Colombiana 14: 62–93: [The birds of Serranía de Perijá: The northernmost avifauna of the Andes](http://asociacioncolombianadeornitologia.org/wp-content/uploads/2014/12/MS1223.pdf) and [photo album](https://www.flickr.com/photos/amcuervo/sets/72157648905991251/)",
#             "animal-seen": "yes",
#             "playback-used": "yes",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "234286",
#             "gen": "Grallaria",
#             "sp": "saltuensis",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Perija Antpitta",
#             "rec": "Andres M. Cuervo",
#             "cnt": "Colombia",
#             "loc": "Cesar, Manaure, Serranía del Perijá, arriba de El Cinco",
#             "lat": "10.3643",
#             "lon": "-72.9458",
#             "alt": "2525",
#             "type": "call, short song?",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/234286",
#             "file": "https://xeno-canto.org/234286/download",
#             "file-name": "XC234286-saltuensis_136_AMC896.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234286/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234286/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/AREXYHFFGC/234286/colour.png",
#                 "full": ""
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "3:14",
#             "time": "07:43",
#             "date": "2008-07-13",
#             "uploaded": "2015-04-05",
#             "also": [
#                 "Zimmerius improbus",
#                 "Myiothlypis nigrocristata",
#                 "Catharus fuscater",
#                 "Diglossa albilatera",
#                 "Patagioenas fasciata",
#                 "Scytalopus perijanus",
#                 "Aulacorhynchus albivitta"
#             ],
#             "rmk": "Perija 136. Male collected (ICN 36771). Check out this paper by López-O. et al. 2014 in Ornitología Colombiana 14: 62–93: [The birds of Serranía de Perijá: The northernmost avifauna of the Andes](http://asociacioncolombianadeornitologia.org/wp-content/uploads/2014/12/MS1223.pdf) and [photo album](https://www.flickr.com/photos/amcuervo/sets/72157648905991251/)",
#             "animal-seen": "yes",
#             "playback-used": "no",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "234208",
#             "gen": "Grallaria",
#             "sp": "spatiator",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Sierra Nevada Antpitta",
#             "rec": "Fabrice Schmitt",
#             "cnt": "Colombia",
#             "loc": "San Lorenzo, Sierra Nevada de Santa Marta",
#             "lat": "11.1053",
#             "lon": "-74.0472",
#             "alt": "2400",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/234208",
#             "file": "https://xeno-canto.org/234208/download",
#             "file-name": "XC234208-Rufous Antpitta_spatiator_SanLorenzo_Col_26mar2015_FSchmitt.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/234208/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/234208/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/234208/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/234208/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-sa/4.0/",
#             "q": "A",
#             "length": "0:13",
#             "time": "08:00",
#             "date": "2015-03-26",
#             "uploaded": "2015-04-05",
#             "also": [],
#             "rmk": "",
#             "animal-seen": "no",
#             "playback-used": "yes",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "223697",
#             "gen": "Grallaria",
#             "sp": "spatiator",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Sierra Nevada Antpitta",
#             "rec": "Peter Boesman",
#             "cnt": "Colombia",
#             "loc": "Santa Marta Lorenzo road, Magdalena",
#             "lat": "11.1035",
#             "lon": "-74.0609",
#             "alt": "500 - 2500",
#             "type": "song",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/223697",
#             "file": "https://xeno-canto.org/223697/download",
#             "file-name": "XC223697-Rufous Antpitta  8590.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/OOECIWCSWV/223697/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/OOECIWCSWV/223697/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/OOECIWCSWV/223697/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/OOECIWCSWV/223697/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-nd/4.0/",
#             "q": "A",
#             "length": "0:24",
#             "time": "06:00",
#             "date": "1994-01-03",
#             "uploaded": "2015-03-22",
#             "also": [],
#             "rmk": "ID certainty 100%. (Archiv. tape 24 side A track 55 seq. B)",
#             "animal-seen": "unknown",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "44100",
#             "annotation-set": []
#         },
#         {
#             "id": "102559",
#             "gen": "Grallaria",
#             "sp": "spatiator",
#             "ssp": "",
#             "grp": "birds",
#             "en": "Sierra Nevada Antpitta",
#             "rec": "Fabrice Schmitt",
#             "cnt": "Colombia",
#             "loc": "San Lorenzo ridge",
#             "lat": "11.1167",
#             "lon": "-74.0834",
#             "alt": "2500",
#             "type": "call",
#             "sex": "",
#             "stage": "",
#             "method": "field recording",
#             "url": "//xeno-canto.org/102559",
#             "file": "https://xeno-canto.org/102559/download",
#             "file-name": "Rufous Antpitta_call_SanLorenzo_Co_24avr2010_FS.mp3",
#             "sono": {
#                 "small": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/102559/grey-small.png",
#                 "med": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/102559/grey-medium.png",
#                 "large": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/102559/colour.png",
#                 "full": "//xeno-canto.org/sounds/spectrograms/FPAGKPAQYO/102559/colour.png"
#             },
#             "osci": {
#                 "small": "",
#                 "med": "",
#                 "large": ""
#             },
#             "lic": "//creativecommons.org/licenses/by-nc-nd/2.5/",
#             "q": "A",
#             "length": "0:23",
#             "time": "10:30 AM",
#             "date": "2010-04-24",
#             "uploaded": "2012-05-30",
#             "also": [],
#             "rmk": "after playback",
#             "animal-seen": "unknown",
#             "playback-used": "unknown",
#             "temp": "",
#             "regnr": "",
#             "auto": "no",
#             "dvc": "",
#             "mic": "",
#             "smp": "48000",
#             "annotation-set": []
#         }
#     ]
# }
